# %%
#Lab 3 - IA e Robótica - Redes Neurais

#Bruno Osse Brigide - RA: 22.119.047-3
#Vitor dos Santos - RA: 22.119.043-2

# %%
#imports

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPRegressor

# %%
#Caso de teste 4 arch 1

print('Caso de teste 4 arch 1')
arquivo = np.load('teste4.npy')
x = arquivo[0]
y = np.ravel(arquivo[1])

hidden_layer_size = 50
max_iter = 150000
n_iter_no_change = 1000
activation = 'tanh'

regr = MLPRegressor(hidden_layer_sizes=(hidden_layer_size, 20),
                    max_iter=max_iter,
                    activation=activation, #{'identity', 'logistic', 'tanh', 'relu'},
                    solver='adam',
                    learning_rate = 'adaptive',
                    n_iter_no_change=n_iter_no_change)
print('\nTreinando RNA com:')
print('Número de camadas escondidas: ', hidden_layer_size)
print('Número de iterações: ', max_iter)
print('Número de iterações sem mudanças:', n_iter_no_change)
print('Ativação: ', activation)

regr = regr.fit(x,y)



print('\nPreditor')
y_est = regr.predict(x)

#plot do primeiro caso de teste

plt.figure(figsize=[14,7])

#plot curso original
plt.subplot(1,3,1)
plt.plot(x,y)

#plot aprendizagem
plt.subplot(1,3,2)
plt.plot(regr.loss_curve_)

#plot regressor
plt.subplot(1,3,3)
plt.plot(x,y,linewidth=1,color='yellow')
plt.plot(x,y_est,linewidth=2)




plt.show()
# Out:
# Caso de teste 4 arch 1
#
# Treinando RNA com:
# Número de camadas escondidas:  50
# Número de iterações:  150000
# Número de iterações sem mudanças: 1000
# Ativação:  tanh
#
# Preditor

# %%
#Caso de teste 4 arch 2

print('Caso de teste 4 arch 2')
arquivo = np.load('teste4.npy')
x = arquivo[0]
y = np.ravel(arquivo[1])

hidden_layer_size = 50
max_iter = 15000
n_iter_no_change = 100
activation = 'tanh'

regr = MLPRegressor(hidden_layer_sizes=(hidden_layer_size, 20, 20),
                    max_iter=max_iter,
                    activation=activation, #{'identity', 'logistic', 'tanh', 'relu'},
                    solver='adam',
                    learning_rate = 'adaptive',
                    n_iter_no_change=n_iter_no_change)
print('\nTreinando RNA com:')
print('Número de camadas escondidas: ', hidden_layer_size)
print('Número de iterações: ', max_iter)
print('Número de iterações sem mudanças:', n_iter_no_change)
print('Ativação: ', activation)

regr = regr.fit(x,y)



print('\nPreditor')
y_est = regr.predict(x)

#plot do primeiro caso de teste

plt.figure(figsize=[14,7])

#plot curso original
plt.subplot(1,3,1)
plt.plot(x,y)

#plot aprendizagem
plt.subplot(1,3,2)
plt.plot(regr.loss_curve_)

#plot regressor
plt.subplot(1,3,3)
plt.plot(x,y,linewidth=1,color='yellow')
plt.plot(x,y_est,linewidth=2)




plt.show()
# Out:
# Caso de teste 4 arch 2
#
# Treinando RNA com:
# Número de camadas escondidas:  50
# Número de iterações:  15000
# Número de iterações sem mudanças: 100
# Ativação:  tanh
# C:\Users\vitor\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (15000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Preditor

# %%
#Caso de teste 4 arch 3

print('Caso de teste 4 arch 3')
arquivo = np.load('teste4.npy')
x = arquivo[0]
y = np.ravel(arquivo[1])

hidden_layer_size = 200
max_iter = 100000
n_iter_no_change = 1000
activation = 'tanh'

regr = MLPRegressor(hidden_layer_sizes=(hidden_layer_size, 50, 50),
                    max_iter=max_iter,
                    activation=activation, #{'identity', 'logistic', 'tanh', 'relu'},
                    solver='adam',
                    learning_rate = 'adaptive',
                    n_iter_no_change=n_iter_no_change)
print('\nTreinando RNA com:')
print('Número de camadas escondidas: ', hidden_layer_size)
print('Número de iterações: ', max_iter)
print('Número de iterações sem mudanças:', n_iter_no_change)
print('Ativação: ', activation)

regr = regr.fit(x,y)



print('\nPreditor')
y_est = regr.predict(x)

#plot do primeiro caso de teste

plt.figure(figsize=[14,7])

#plot curso original
plt.subplot(1,3,1)
plt.plot(x,y)

#plot aprendizagem
plt.subplot(1,3,2)
plt.plot(regr.loss_curve_)

#plot regressor
plt.subplot(1,3,3)
plt.plot(x,y,linewidth=1,color='yellow')
plt.plot(x,y_est,linewidth=2)




plt.show()
# Out:
# Caso de teste 4 arch 3
#
# Treinando RNA com:
# Número de camadas escondidas:  200
# Número de iterações:  100000
# Número de iterações sem mudanças: 1000
# Ativação:  tanh
#
# Preditor
